# %%
from matplotlib import pyplot as plt

years = [1950, 1960,1970, 1980, 1990, 2000, 2010]
gdp = [300.2, 543.3, 1075.9, 2862.5, 5979.6, 10289.7, 14958.3]

# x 축에 연도, y축에  GDP가 그려진 선 그래프
plt.plot(years, gdp, color='green', marker='o', linestyle='solid')

# 그래프 제목 추가
plt.title("Nominal GDP")

#y축에 레이블 추가
plt.ylabel("Billions of $")
plt.show()

# %%
# 3.2 막대 그래프
movies = ["Annie Hall", "Ben-Hur", "Casablanc", "Gandhi","West Side Story"]
num_oscars = [5,11,3,8, 10]

# 막대 너비의 기본 값이 0.8
#막대가 가운데로 올수 있게 왼쪽 좌표에 0.1씩 추가
xs =[i + 0.1 for i, _ in enumerate(movies)]

#왼편으로부터 x축의 위치가 xs이고 높이가 num_oscars인 막대 그리기
plt.bar(xs, num_oscars)
plt.ylabel('# of Academy Awards')
plt.title("My Favorite Movies")

# 막대의 가운데에 오도록 영화 제목 레이블 달기
plt.xticks([i + 0.5 for i, _ in enumerate(movies)], movies)
plt.show()

# %%
# 3.3 히스토그램
from collections import Counter

grades = [83, 95, 91, 87, 70, 0, 85, 82, 100, 67, 73, 77, 0]
decile = lambda grade: grade //  10*10
histogram = Counter(decile(grade) for grade in grades)

plt.bar([x -4 for x in histogram.keys()],
        histogram.values(),
        8)

plt.axis([-5, 105, 0, 5])  #x 축은 -5부터 105
                                        # y축은 0부터 5
    
plt.xticks([10*i for i in range(11)])  #x 축의 레이블은 0, 10, ..., 100
plt.xlabel("Decile")
plt.ylabel('# of Students')
plt.title("Distribution of Exam 1 Grades")
plt.show()

# %%
# 3.4 그래프
mentions = [500, 505]
years = [2013, 2014]

plt.bar([2012.6, 2013.6], mentions, 0.8)
plt.xticks(years)
plt.ylabel("# of times I heard someone say 'data science'")

plt.ticklabel_format(useOffset=False)

# 오해 불러일으키는 y축은 500이상 부분만 보여줌
plt.axis( [2012.5, 2014.5, 499, 506])
plt.title("Look at the 'Huge' Increase!")
plt.show()

# %%
# 3.5 그래프
mentions = [500, 505]
years = [2013, 2014]

plt.bar([2013, 2014] ,     #막대 위치
        mentions, #높이
        0.8)  # 너비
plt.xticks(years)
plt.ylabel("# of times I heard someone say 'data science'")

plt.ticklabel_format(useOffset=False)


plt.axis([2012.5, 2014.5, 0, 550])
plt.title("Not So Hugh Anymore")
plt.show()

# %% [markdown]
# 선 그래프

# %%
#3.6 그래프
variance = [1,2,4, 8, 16, 32, 64, 128, 256]
bias_squared = [256, 128, 64, 32, 16, 8, 4, 2, 1]
total_error = [x+y for x, y in zip(variance, bias_squared)]
xs = [i for i, _ in enumerate(variance)]

# 한 차트에 여러개 seriew 그리기 위해서
# plt. plot 을 여러번 호출 가능
plt.plot(xs, variance, 'g-', label='variance') #초록색 실선
plt.plot(xs, bias_squared, 'r-', label='bias^2') #붉은색 점선
plt.plot(xs, total_error, 'b:', label='total error') #파aaaaa란색 점선

# 각 series에 label을 미리 달아 놨기 때문에
# 범례(legend)를 어렵지 않게 그리기 가능.
# loc =9 는 "top center(위쪽 중앙)" 의미
plt.legend(loc =9)
plt.xlabel('model complexity')
plt.title("The Bias-Variance Tradeoff")
plt.show()

# %%
#3.7 그래프
friends = [70, 65, 72, 63, 71, 64, 60, 64, 67]
minutes =[175, 170, 205, 120, 220, 130, 105, 145, 190]
labels = ['a', 'b','c', 'd','e','f','g','h','i']

plt.scatter(friends, minutes)

#각 포인트에 레이블을 달자

for label, friend_count, minute_count in zip(labels, friends, minutes):  #zip 은 동일한 개수로 이루어진 자료형 묶어주는 역할함.
    plt.annotate(label,
                xy=(friend_count, minute_count),  #label을 데이터 포인트 근처에 두되
                xytext=(5,-5),  # 약간 떨어져 있게 함
                 textcoords='offset points'
                )
plt.title("Daily Minutes vs. Number of Friends")
plt.xlabel("# of friends")
plt.ylabel("daily minutes spent on the site")
plt.show()

# %%
# 3.8 그래프

test_1_grades = [99, 90, 85, 97, 80]
test_2_grades = [100, 85, 60, 90, 70]

plt.scatter(test_1_grades, test_2_grades)
plt.title("Axes Aren't Comparable")
plt.xlabel("Test 1 grade")
plt.ylabel("test 2 grade")
plt.show()

# %%
# 3.8 그래프

test_1_grades = [99, 90, 85, 97, 80]
test_2_grades = [100, 85, 60, 90, 70]

plt.scatter(test_1_grades, test_2_grades)

plt.axis("equal")
plt.title("Axes Aren Comparable")
plt.xlabel("Test 1 grade")
plt.ylabel("test 2 grade")
plt.show()
